# %% [markdown]
# # we will first see about some basic plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#to show all our data point inside the jupyter notebook

# %%
# %matplotlib inline

# %%
year = [1950,1970,1990,2010]
pop = [ 2.5,3.6,5.2, 6.9]
plt.plot(year ,pop)
plt.xlabel('year')
plt.ylabel('popolation')
plt.title('world Population projection')
plt.yticks([0,2,4,6,8,10] , [0,'2B','4B','6B','8B','10B',])   # in this manner we can add a second argumen and
#make plot more visible and precise like giving it a unit
plt.show()

# %% [markdown]
# ##### We can plot scatter plot instead of a line plot

# %%
plt.scatter(year ,pop)
plt.xlabel('year')
plt.ylabel('popolation')
plt.title('world Population projection')
plt.yticks([0,2,4,6,8,10] , [0,'2B','4B','6B','8B','10B',])   # in this manner we can add a second argumen and
#make plot more visible and precise like giving it a unit
plt.show()

# %%
year_world_bank = np.linspace(1950 , 2100 ,2100-1950+1)  # we generated year equali spaced

# %%
pop_world_bank = np.round(np.linspace(2.53 , 10.85 , 2100-1950+1) , 2)  # we generated population till 2100

# %%
## let see the graph

# %%
plt.scatter(year_world_bank, pop_world_bank, s = pop )  # s=pop will arrange the size of bubbles same as how big they are
plt.xlabel('year')
plt.ylabel('popolation')
plt.title('world Population projection')
plt.show()

# %%
# now we will change our data and run the graph again
year = [1800,1850,1900] +year
pop = [1.0,1.205,1.506] +pop

# %%
plt.plot(year ,pop)
plt.xlabel('year')
plt.ylabel('popolation')
plt.title('world Population projection')
plt.yticks([0,2,4,6,8,10] , [0,'2B','4B','6B','8B','10B',])
plt.show() # Hence our graph will become moreinformative

# %% [markdown]
# #### BY using plt.xscale('log')   we can change our scale into 10 to powe scale

# %%
plt.scatter(year, pop, s = pop )  # s=pop will arrange the size of bubbles same as how big they are

# %%
pop = [31.889923, 3.6005229999999999, 33.333216, 12.420476000000001, 40.301926999999999, 20.434176000000001, 8.199783, 0.70857300000000001, 150.448339, 10.392226000000001, 8.0783140000000007, 9.1191519999999997, 4.5521979999999997, 1.6391309999999999, 190.01064700000001, 7.3228580000000001, 14.326203, 8.3905049999999992, 14.131857999999999, 17.696293000000001, 33.390141, 4.3690379999999998, 10.238807, 16.284741, 1318.683096, 44.227550000000001, 0.71096000000000004, 64.606758999999997, 3.8006099999999998, 4.1338840000000001, 18.013408999999999, 4.4933120000000004, 11.416987000000001, 10.228744000000001, 5.4681199999999999, 0.49637399999999998, 9.3196220000000007, 13.75568, 80.264543000000003, 6.9396880000000003, 0.55120100000000005, 4.9065849999999998, 76.511887000000002, 5.2384599999999999, 61.083916000000002, 1.4548669999999999, 1.6883589999999999, 82.400996000000006, 22.873338, 10.706289999999999, 12.572927999999999, 9.9478139999999993, 1.4720409999999999, 8.5028140000000008, 7.4837629999999997, 6.9804120000000003, 9.9561080000000004, 0.301931, 1110.3963309999999, 223.547, 69.453569999999999, 27.499638000000001, 4.1090859999999996, 6.426679, 58.147733000000002, 2.780132, 127.467972, 6.0531930000000003, 35.610177, 23.301725000000001, 49.044789999999999, 2.5055589999999999, 3.921278, 2.0126490000000001, 3.1939419999999998, 6.0369140000000003, 19.167653999999999, 13.327078999999999, 24.821286000000001, 12.031795000000001, 3.2700650000000002, 1.250882, 108.700891, 2.8741270000000001, 0.68473600000000001, 33.757174999999997, 19.951656, 47.761980000000001, 2.0550799999999998, 28.901789999999998, 16.570613000000002, 4.1157709999999996, 5.6753559999999998, 12.894864999999999, 135.03116399999999, 4.6279260000000004, 3.2048969999999999, 169.27061699999999, 3.2421730000000002, 6.6671469999999999, 28.674757, 91.077286999999998, 38.518241000000003, 10.642836000000001, 3.942491, 0.79809399999999997, 22.276056000000001, 8.8605879999999999, 0.19957900000000001, 27.601037999999999, 12.267493, 10.150264999999999, 6.1445619999999996, 4.5530090000000003, 5.4475020000000001, 2.0092449999999999, 9.1187729999999991, 43.997827999999998, 40.448191000000001, 20.378239000000001, 42.292929000000001, 1.1330659999999999, 9.0310880000000004, 7.5546610000000003, 19.314747000000001, 23.174294, 38.13964, 65.068149000000005, 5.7015789999999997, 1.056608, 10.276158000000001, 71.158647000000002, 29.170397999999999, 60.776237999999999, 301.13994700000001, 3.4474960000000001, 26.084662000000002, 85.262355999999997, 4.018332, 22.211742999999998, 11.746034999999999, 12.311143]

# %%
np_pop = np.array(pop)

# %%
gdp_cap = [974.58033839999996, 5937.0295259999984, 6223.3674650000003, 4797.2312670000001, 12779.379639999999, 34435.367439999995, 36126.492700000003, 29796.048340000001, 1391.253792, 33692.605080000001, 1441.2848730000001, 3822.137084, 7446.2988029999997, 12569.851769999999, 9065.8008250000003, 10680.792820000001, 1217.0329939999999, 430.07069159999998, 1713.7786860000001, 2042.0952400000001, 36319.235009999997, 706.01653699999997, 1704.0637240000001, 13171.638849999999, 4959.1148540000004, 7006.5804189999999, 986.14787920000003, 277.55185870000003, 3632.5577979999998, 9645.06142, 1544.7501119999999, 14619.222719999998, 8948.1029230000004, 22833.308509999999, 35278.418740000001, 2082.4815670000007, 6025.3747520000015, 6873.2623260000009, 5581.1809979999998, 5728.3535140000004, 12154.089749999999, 641.36952360000021, 690.80557590000001, 33207.0844, 30470.0167, 13206.48452, 752.74972649999995, 32170.37442, 1327.6089099999999, 27538.41188, 5186.0500030000003, 942.6542111, 579.23174299999982, 1201.637154, 3548.3308460000007, 39724.978669999997, 18008.944439999999, 36180.789190000003, 2452.210407, 3540.6515639999998, 11605.71449, 4471.0619059999999, 40675.996350000001, 25523.277099999999, 28569.719700000001, 7320.8802620000015, 31656.068060000001, 4519.4611709999999, 1463.249282, 1593.06548, 23348.139730000006, 47306.989780000004, 10461.05868, 1569.3314419999999, 414.5073415, 12057.49928, 1044.7701259999999, 759.34991009999999, 12451.6558, 1042.581557, 1803.151496, 10956.991120000001, 11977.57496, 3095.7722710000007, 9253.896111, 3820.1752299999998, 823.68562050000003, 944.0, 4811.0604290000001, 1091.359778, 36797.933319999996, 25185.009109999999, 2749.3209649999999, 619.67689239999982, 2013.9773049999999, 49357.190170000002, 22316.192869999999, 2605.94758, 9809.1856360000002, 4172.8384640000004, 7408.9055609999996, 3190.4810160000002, 15389.924680000002, 20509.64777, 19328.709009999999, 7670.122558, 10808.47561, 863.08846390000019, 1598.4350890000001, 21654.83194, 1712.4721360000001, 9786.5347139999994, 862.54075610000018, 47143.179640000002, 18678.314350000001, 25768.257590000001, 926.14106830000003, 9269.6578079999999, 28821.063699999999, 3970.0954069999998, 2602.3949950000001, 4513.4806429999999, 33859.748350000002, 37506.419070000004, 4184.5480889999999, 28718.276839999999, 1107.482182, 7458.3963269999977, 882.9699437999999, 18008.509239999999, 7092.9230250000001, 8458.2763840000007, 1056.3801209999999, 33203.261279999999, 42951.65309, 10611.46299, 11415.805689999999, 2441.5764039999999, 3025.3497980000002, 2280.769906, 1271.211593, 469.70929810000007]

# %%
np_gdp_cap = np.array(gdp_cap)

# %%
np.corrcoef(np_gdp_cap , np_pop)   # corelation bw these are very low which is unusual
# Out:
# array([[ 1.       , -0.0556756],
#        [-0.0556756,  1.       ]])

# %%
plt.scatter(gdp_cap, np_pop, s = np_pop,c='c',alpha=0.6) # c='c'wll add some colur to our bubbles c could be list of colors
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

plt.text(1550, 1100, 'India',color = 'r')
plt.text(2900, 1250, 'China',color = 'b')
plt.grid(True)
# Display the plot
plt.show()  # s=np_pop will arrange the size of bubbles as population
# alpha = 0.5 this can be from 0 to 1 ot adds transperancy to the bubbles
# by using plt.text( x , y , name) # we can add name on the graph
# in case we want multiple colours for all of our bubbles we should use dictonary and assign them a key value pair

# %% [markdown]
# ### Lets see how histogram are made and what they represent
#
#
# ###### they give idea of distribution of points in a particular interval height of histagram will tell about number of data points within tha bin

# %%
 help(plt.hist)  # you can see differant args given in histogram function

# %%
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' } # this is a dictionary

# %%
europe.keys() # we can find the keys in dictionary
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])

# %%
europe['spain'] # by calling key value we can access the value
# Out:
# 'madrid'

# %% [markdown]
# ### Dictionaries key should be unique if we added two value to same key the last one will be retained and keys
# ### should be immutable object

# %%
europe['India'] = 'New Delhi' # this is way to add new key value pair in exixting dictionary

# %%
europe
# Out:
# {'India': 'New Delhi',
#  'france': 'paris',
#  'germany': 'berlin',
#  'norway': 'oslo',
#  'spain': 'madrid'}

# %%
"India" in europe   # this is the way to check that this particular key does exist in my dictionary
# Out:
# True

# %%
europe['India'] = 'nayi dilli' # this is the way to update our existing key's value

# %%
europe
# Out:
# {'India': 'nayi dilli',
#  'france': 'paris',
#  'germany': 'berlin',
#  'norway': 'oslo',
#  'spain': 'madrid'}

# %%
del(europe['spain']) # this is the way to delete any key valu pair

# %%
europe
# Out:
# {'India': 'nayi dilli',
#  'france': 'paris',
#  'germany': 'berlin',
#  'norway': 'oslo'}

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }

# we can see that a dictionary can contain contain dictionary itself

# %%
# Print out the capital of France
print(europe['france']['capital'])

# this is the way to access the element inside DIctionary of dictionaries
# Out:
# paris

# %%
data = {'capital' : 'rome' , 'population' : 59.83}

# Add data to europe under key 'italy'
europe['italy'] = data
# way to add some extra key value pair to the existing Dictionary of dictionaries

# %% [markdown]
# #### We can see that order in the dictionary is not same as it was written . so note that dictionary is inherently unordered.

# %%
europe
# Out:
# {'france': {'capital': 'paris', 'population': 66.03},
#  'germany': {'capital': 'berlin', 'population': 80.62},
#  'italy': {'capital': 'rome', 'population': 59.83},
#  'norway': {'capital': 'oslo', 'population': 5.084},
#  'spain': {'capital': 'madrid', 'population': 46.77}}

# %% [markdown]
# ### now let us have some hand dirty on pandas

# %%
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# %%
# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = {'country' : names , 'drives_right' : dr , 'cars_per_cap' : cpc}

# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict)

# Print cars
print(cars)
# this is way to create the pandas dataframe from a dictionary
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True

# %%
# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels


# Print cars again
print(cars)

# This is the way to change the index of the dataframe
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
cars.to_csv('cars.csv.txt')

# %%
df = pd.read_csv('cars.csv.txt')

# %%
df # every time if we do not mention pandas willl provide its own indexing
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
df = pd.read_csv('cars.csv.txt' ,index_col=0) # by this we can asssign that from what column we want to start our index

# %%
df
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
df['country'] # this will yield a new data type called pandas.core.series.Series
# Out:
# US     United States
# AUS        Australia
# JAP            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
# if we want to store as df so we have to use [['']]
df[['country']]
# Out:
#            country
# US   United States
# AUS      Australia
# JAP          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt

# %%
type(df[['country']]) # this is a data frame
# Out:
# pandas.core.frame.DataFrame

# %%
df[['country','drives_right']]  # to select multiple column a sub data frame
# Out:
#            country  drives_right
# US   United States          True
# AUS      Australia         False
# JAP          Japan         False
# IN           India         False
# RU          Russia          True
# MOR        Morocco          True
# EG           Egypt          True

# %%
df[1:4] # for row 1,2,3
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# JAP           588      Japan         False
# IN             18      India         False

# %% [markdown]
# #### to extend our understatndin of data we use
# ####      .loc(label_based)
# ####      .iloc(integer position_based)

# %%
df.loc['RU'] # we will get serires
# Out:
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object

# %%
df.loc[['RU']] # we will get data frame
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True

# %%
df.loc[['RU','IN','US']]  # for selecting multiple rows
# Out:
#     cars_per_cap        country  drives_right
# RU           200         Russia          True
# IN            18          India         False
# US           809  United States          True

# %%
df.loc[['RU','IN','US'],['country']] # df.loc[[row] , [column]] this is the main formar row is list & column is also a list
# Out:
#           country
# RU         Russia
# IN          India
# US  United States

# %%
df.loc[['RU','IN','US'],:] # some row all column
# Out:
#     cars_per_cap        country  drives_right
# RU           200         Russia          True
# IN            18          India         False
# US           809  United States          True

# %%
df.loc[:,['country']] # all row one column
# Out:
#            country
# US   United States
# AUS      Australia
# JAP          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt

# %%
df.iloc[1] # series
# Out:
# cars_per_cap          731
# country         Australia
# drives_right        False
# Name: AUS, dtype: object

# %%
df.iloc[[1]] # data frame  i stands for integer same work as loc but by positoin
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False

# %%
df.iloc[[1,2,3]]
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# JAP           588      Japan         False
# IN             18      India         False

# %%
df.iloc[[1,2,3],[0,1]] # follw the trend of df.iloc[[row indexing] , [column indexing]]
# Out:
#      cars_per_cap    country
# AUS           731  Australia
# JAP           588      Japan
# IN             18      India

# %%
# Create arrays

my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18
print(my_house>=18)

# my_house less than your_house
print(my_house<your_house)
# Out:
# [ True  True False False]
# [False  True  True False]

# %%
np.logical_and(my_house>=18 , my_house<=20)  # by this method we can inspect our NumPy array in intervals
# Out:
# array([ True,  True, False, False])

# %%
np.logical_or(my_house>=10 , my_house<=20) # all type of operation are available
# Out:
# array([ True,  True,  True,  True])

# %%
my_house[np.logical_and(my_house>=18 , my_house<=20)] # so those value corresponds to true will be selected
# Out:
# array([18., 20.])

# %% [markdown]
# ## if, elif, else
# #### if any condition both **if** & **elif** holds true then only **if** block will run and control will not reaach upto the **elif** block
# #### in case of nested **if** **elif** and **else** control starts from up if any block will run the remaining block will not run

# %% [markdown]
# # now we will learn filtering pandas data frame by some other methods

# %%
df   ## this is our data frame
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# ### we will write a code to list all those countries having cars_per_cap greater than 500
# ####          This involves three steps
# ####          1.Get column (series)
# ####          2.compare
# ####          3.Subset DF by using bool

# %%
df['cars_per_cap'] # first get that column  this will give a series
# Out:
# US     809
# AUS    731
# JAP    588
# IN      18
# RU     200
# MOR     70
# EG      45
# Name: cars_per_cap, dtype: int64

# %%
df['cars_per_cap']>500 # create a bolean series
# Out:
# US      True
# AUS     True
# JAP     True
# IN     False
# RU     False
# MOR    False
# EG     False
# Name: cars_per_cap, dtype: bool

# %%
is_huge = df['cars_per_cap']>500  # store it in a data frame

# %%
is_huge
# Out:
# US      True
# AUS     True
# JAP     True
# IN     False
# RU     False
# MOR    False
# EG     False
# Name: cars_per_cap, dtype: bool

# %%
df[is_huge] # the country having cars_per_cap greater than 500 will be listed True will be printed and False will be skip
## a Data Frame
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False

# %%
df[df['cars_per_cap']>500 ] # one liner code  To combine all threee stepsg
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False

# %%
# suppose we want that car_per_cap shoul be greater than 100 but less than 600
df[np.logical_and(df['cars_per_cap'] >100 , df['cars_per_cap']<600)]
# simple one line code
# Out:
#      cars_per_cap country  drives_right
# JAP           588   Japan         False
# RU            200  Russia          True

# %%
list_dist = [18.0, 20.0, 10.75, 9.50]

# %%
for distance in list_dist:
    print(distance) 
# we dont have access over index on which we are iterating over
# Out:
# 18.0
# 20.0
# 10.75
# 9.5

# %%
# now we will use something called numerate
for index ,distance in enumerate(list_dist):
    print('index ' +str(index) + ': ' + str(distance))
# Out:
# index 0: 18.0
# index 1: 20.0
# index 2: 10.75
# index 3: 9.5

# %%
for c in "alphabet":
    print(c.capitalize())
# so we can iterate over string also
# Out:
# A
# L
# P
# H
# A
# B
# E
# T

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# %%
europe
# Out:
# {'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'spain': 'madrid'}

# %%
for key ,value in europe:
    print(key + '----' + value) # python give error this can be fixed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-e0472793d2fb> in <module>()
# ----> 1 for key ,value in europe:
#       2     print(key + '----' + value) # python give error this can be fixed
#
# ValueError: too many values to unpack (expected 2)

# %%
# by calling method .items()
for key ,value in europe.items():
    print(key + '----' + value)
# may be totaly random
# Out:
# spain----madrid
# france----paris
# germany----berlin
# norway----oslo

# %%
year_n = np.array([1800, 1850, 1900, 1950])
pop_n = np.array([ 2.5,3.6,5.2, 6.9])

# %%
np_2d = np.array([year_n , pop_n])

# %%
for value in np_2d:
    print(value)
# this code will print simply two numpy array but if we want to go through the each element we hawe to
# Out:
# [1800. 1850. 1900. 1950.]
# [2.5 3.6 5.2 6.9]

# %%
# use method np.editor
for values in np.nditer(np_2d):
    print(values)
# all value will be printed
# Out:
# 1800.0
# 1850.0
# 1900.0
# 1950.0
# 2.5
# 3.6
# 5.2
# 6.9

# %%
df
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# #### now we will learn how to iterate iver pandas datasframe using loop

# %%
for val in df:
    print(val)
# this will give some unexpected result
# Out:
# cars_per_cap
# country
# drives_right

# %%
# now we can use some methods
for val ,series in df.iterrows():
    print(val)
    print(series)
    
# in each iteration val will be  label or you can say the index name
# because this series contain pandas series so we can take any information we want from this
# Out:
# US
# cars_per_cap              809
# country         United States
# drives_right             True
# Name: US, dtype: object
# AUS
# cars_per_cap          731
# country         Australia
# drives_right        False
# Name: AUS, dtype: object
# JAP
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object
# IN
# cars_per_cap       18
# country         India
# drives_right    False
# Name: IN, dtype: object
# RU
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object
# MOR
# cars_per_cap         70
# country         Morocco
# drives_right       True
# Name: MOR, dtype: object
# EG
# cars_per_cap       45
# country         Egypt
# drives_right     True
# Name: EG, dtype: object

# %%
for val ,series in df.iterrows():
    print(val +':' + str(series['drives_right']))
    
# this is how we take out the drives right for each country and printed it
# Out:
# US:True
# AUS:False
# JAP:False
# IN:False
# RU:True
# MOR:True
# EG:True

# %%
for val , series in df.iterrows():
    df.loc[val ,'bol_value'] = int(series['drives_right'])
# by this method we smartly converted True = 1 & False = 0 and added a new column and by assigning it name 'bol_value' 
# in every iteration we assigned the value
# but this is not be efficient if we are working with huge dataset use another method called apply

# %%
df
# Out:
#      cars_per_cap        country  drives_right  bol_value
# US            809  United States          True        1.0
# AUS           731      Australia         False        0.0
# JAP           588          Japan         False        0.0
# IN             18          India         False        0.0
# RU            200         Russia          True        1.0
# MOR            70        Morocco          True        1.0
# EG             45          Egypt          True        1.0

# %% [markdown]
# #### apply is used to apply a function on a column in element-wise fashion

# %%
df['bol_value']= df['drives_right'].apply(int) # same thing what we did by going through for loop

# %%
df # this is more efficient
# Out:
#      cars_per_cap        country  drives_right  bol_value
# US            809  United States          True          1
# AUS           731      Australia         False          0
# JAP           588          Japan         False          0
# IN             18          India         False          0
# RU            200         Russia          True          1
# MOR            70        Morocco          True          1
# EG             45          Egypt          True          1

# %%
for val , series in df.iterrows():
    df.loc[val ,'COUNTRY'] = series['country'].upper()
# this will add a new country column with all column having upper case letter
# we will  do it by another method as well

# %%
df
# Out:
#      cars_per_cap        country  drives_right  bol_value        COUNTRY
# US            809  United States          True          1  UNITED STATES
# AUS           731      Australia         False          0      AUSTRALIA
# JAP           588          Japan         False          0          JAPAN
# IN             18          India         False          0          INDIA
# RU            200         Russia          True          1         RUSSIA
# MOR            70        Morocco          True          1        MOROCCO
# EG             45          Egypt          True          1          EGYPT

# %%
# add lower case of country plus (code in upper case as well)
df['countr_code']= df['country'].apply(str.upper) 
# second method

# %%
df
# Out:
#      cars_per_cap        country  drives_right  bol_value        COUNTRY  \
# US            809  United States          True          1  UNITED STATES
# AUS           731      Australia         False          0      AUSTRALIA
# JAP           588          Japan         False          0          JAPAN
# IN             18          India         False          0          INDIA
# RU            200         Russia          True          1         RUSSIA
# MOR            70        Morocco          True          1        MOROCCO
# EG             45          Egypt          True          1          EGYPT
#
#        countr_code
# US   UNITED STATES
# AUS      AUSTRALIA
# JAP          JAPAN
# IN           INDIA
# RU          RUSSIA
# MOR        MOROCCO
# EG           EGYPT

# %% [markdown]
# ### let us generate some random number
# #### they also called pseudo-random numbers because they are generated by a mathematical formula starting fromm a seed which can be also set manually
# #### same **seed** : same **number**
# ###### this ensures reproducebility if you run different version of same algo you will know that they are using same  random numbers and can make fair comparision between these two

# %%
np.random.rand() # it will generate a random number every time we run between 0 and 1
# Out:
# 0.2268514535642031

# %%
np.random.seed(123)  # if we fix the seed then number will be same

# %%
np.random.rand()
# Out:
# 0.6964691855978616

# %%
coin = np.random.randint(0,2) # randomly generate 0 or 1  ## confused

# %%
coin ==0
# Out:
# False

# %%
coin = np.random.randint(0,2)

# %%
np.random.randint(0,7)
# Out:
# 6

# %%
np.random.randint(0,7)
# Out:
# 1

# %%
np.random.randint(0,7)
# Out:
# 0

# %%
np.random.randint(0,7) # every time defferent random number
# Out:
# 0

# %%
np.random.seed(145)
outcomes = []
for x in range(10):
    coin = np.random.randint(0,2)
    if coin == 0:
        outcomes.append('heads')
    else:
        outcomes.append('tails')
        
print(outcomes) 
# randomly head and tail will be appended in the outcomes
# Out:
# ['tails', 'tails', 'heads', 'tails', 'heads', 'tails', 'heads', 'heads', 'tails', 'heads']

# %%
np.random.seed(123)
tails = [0]
for x in range(10):
    coin = np.random.randint(0,2)
    tails.append(tails[x] +coin)

print(tails)    
# if one is generated then tail will be increased by 1 hencce the final element will tell us how many times tail appears
# if seed is same then result also will be same but if we change the seed then result will be altered
# Out:
# [0, 0, 1, 1, 1, 1, 1, 1, 2, 3, 3]

# %%
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

# Complete the ___
for x in range(100) :
    
    # Set step: last element in random_walk
    step = random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)

# this is very interesting case mind it and observe it
# but there is stiil something wrong therer is -1 appears at index 15 but it should not be there
# because we can not go at -1 step
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, -1, 0, 5, 4, 3, 4, 3, 4, 5, 6, 7, 8, 7, 8, 7, 8, 9, 10, 11, 10, 14, 15, 14, 15, 14, 15, 16, 17, 18, 19, 20, 21, 24, 25, 26, 27, 32, 33, 37, 38, 37, 38, 39, 38, 39, 40, 42, 43, 44, 43, 42, 43, 44, 43, 42, 43, 44, 46, 45, 44, 45, 44, 45, 46, 47, 49, 48, 49, 50, 51, 52, 53, 52, 51, 52, 51, 52, 53, 52, 55, 56, 57, 58, 57, 58, 59]

# %% [markdown]
# #### this problem can be solved by using max function
# ##### For example, to make sure that a variable x never goes below 10 when you decrease it, you can use:
#
# #### x = max(10, x - 1)

# %%
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        # Replace below: use max to make sure step can't go below 0
        step = max(0,step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)
# now we can see that -1 will not appear at anywhere
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60]

# %% [markdown]
# ### Visualize the walk
# Let's visualize this random walk! Remember how you could use matplotlib to build a line plot?
#
# import matplotlib.pyplot as plt
# plt.plot(x, y)
# plt.show()
# The first list you pass is mapped onto the x axis and the second list is mapped onto the y axis.
# ## important baat
# #### If you pass only one argument, Python will know what to do and will use the index of the list to map onto the x axis, and the values in the list onto the y axis.

# %%
# Plot random_walk
plt.plot(random_walk ,color = 'k')
plt.xlabel("number of tries")
plt.ylabel("number of stairs")

# Show the plot
plt.show()
# this is how he walked up

# %%
#now we will collect the number of tails that we end up with  if we play game by tossing coin 10 times over and over again.
np.random.seed(123)
final_tails = []
'''for x in range(1000000):
    tails = [0]
    for x in range(10):
        coin = np.random.randint(0,2)
        tails.append(tails[x] +coin) #final element will tell us how many times tail appears
    final_tails.append(tails[-1]) # we collected last element in our final list
    
# in 100 how many times we end up with what number of tails
#we will simulate this process 1M times and see what will be outcome 

# all these values represents a distribution that we can visualize'''

# %% [markdown]
# # we will se that 5 times tail occur most of the time and according to probability
# ## it is true that head and tail should come 5-5 times each see the statistics variation

# %%
# let's visualize 
plt.hist(final_tails ,bins=30)

plt.show()

# %%
# we willsimulate the process 10 times to see the trends how it goes 
np.random.seed(123)
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_nw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_nw)
plt.show()
# this will look somewhat dirty

# %%
# Transpose np_aw: np_aw_t
np_nw_t = np.transpose(np_nw)

# Plot np_aw_t and show
plt.plot(np_nw_t)
plt.show()
# this will look better

# %% [markdown]
# ## implement clumsiness
# With this neatly written code of yours, changing the number of times the random walk should be simulated is super-easy. You simply update the range() function in the top-level for loop.
#
# ### There's still something we forgot! You're a bit clumsy and you have a 0.1% chance of falling down. That calls for another random number generation.
# #### Basically, you can generate a random float between 0 and 1. If this value is less than or equal to 0.001, you should reset step to 0.

# %%
np.random.seed(123)
all_walks = []

# Simulate random walk 250 times
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand(0,1)<=0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.

# %%
np.random.seed(123)
all_walks = []

# Simulate random walk 500 times
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks)) # this will convert into aray 

# Select last row from np_aw_t: ends
ends = np_aw_t[-1]

# Plot histogram of ends, display plot

plt.hist(ends ,bins=200)
plt.show()
# how the one data type is changing into

# %%
np_aw_t
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 3,  5,  0, ...,  1,  1,  1],
#        [ 2,  4,  1, ...,  2,  0,  0],
#        ...,
#        [70, 90, 80, ..., 93, 59, 60],
#        [69, 93, 81, ..., 92, 58, 61],
#        [70, 94, 82, ..., 91, 57, 65]])

# %%
np_aw_t[-1]  # this will contain last element of random walk watch the data flow carefully
# Out:
# array([ 70,  94,  82,  66, 107,  49,  72, 116,  65,  78,  87,  47,  81,
#         75,  56,  70,  77,  88,  55,  42,  74,  64,  63,  58,  70,  55,
#         93,  98,  58,  60,  70,  70,  72,  71,  47,  78,  78,  79,  71,
#         83,  71,  56,  63,  94,  49,  72,  63,  74,  61,  61,  79,  91,
#         46,  66,  70,  55,   0,  80,  45,  89,  91,  61,  83,  71,  60,
#         68,  74,  85,  68,  88,  64,  84, 114,  61,  65,  78,  63,  61,
#         90,  96,  83,  77,  80,  71,  87,  73,  60,  85,  84,  76, 105,
#         57,  98,  46,  63, 112,  81,  45, 101,  74,  77,  13,  81,  47,
#         97,  90,  66,  52,  63,  54,  91,  26, 101,  81,  64,  95,  83,
#         99,  75,  75,  61,  97,  57,  94,  76,  82,  86,  52, 122, 110,
#         91,  47,  34,  94, 106,  58,  74,  75,  93,  64,  57,  76, 100,
#         66,  98,  94,  60,  72,  55,  85,  66,  69,  59,  78,  81,  87,
#         75,  58,  80,  97,  75,  67,  22,   6,  78,  87,  87,  80,  80,
# ...
